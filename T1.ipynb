# %%
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt
import pandas as pd
laysub_1 = 'HAR\Combined\Train\LAYING\Subject_1.csv'
x = pd.read_csv(laysub_1)
plt.plot(x)
plt.show()
